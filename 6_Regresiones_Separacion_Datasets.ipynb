# %%
import pandas as pd
import re
import os

# %% [markdown]
# # **| Separación del Dataset Grecia**

# %%
#Cargar desde un archivo .csv
df = pd.read_csv('Grecia.csv')
Grecia = df.drop(['Unnamed: 0'], axis=1)

Grecia.head()
# Out:
#   last_scraped       source                                              name  \
# 0   2024-09-23  city scrape  3 bedrooms, 2 bathrooms, 2nd floor with elevator
# 1   2024-09-23  city scrape      Athens Quality Apartments - Deluxe Apartment
# 2   2024-09-23  city scrape                Athens Quality Apartments - Studio
# 3   2024-09-23  city scrape    AQA-No2 1-bedroom, smart tv, fiber connection,
# 4   2024-09-23  city scrape      AQA-No7, Great mattress, high speed internet
#
#                                          description  \
# 0  The apartment is 3-bedroom apartment with 2-ba...
# 1  Athens Quality Apartments - Deluxe apartment i...
# 2  The Studio is an <br />-excellent located <br ...
# 3  AQA No2 is 1-bedroom apartment (47m2), on the ...
# 4  THE MATTRESS - KING KOIL - Camden Luxury 160x2...
#
#                                neighborhood_overview  host_name  host_since  \
# 0  Ampelokipi district is nice multinational and ...  Emmanouil  2009-09-08
# ...

# %%
# Separar los datos en diferentes datasets basados en el valor de "room_type"
room_type_groups = Grecia.groupby('room_type')

# Crear un diccionario para almacenar los datasets separados
room_type_datasets = {room_type: data for room_type, data in room_type_groups}

# Mostrar los nombres de los datasets creados
room_type_datasets.keys()
# Out:
# dict_keys(['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'])

# %%
for room_type, data in room_type_datasets.items():
    print(f"Dataset: {room_type}")
    display(data.head())
# Out:
# Dataset: Entire home/apt
#   last_scraped       source                                              name  \
# 0   2024-09-23  city scrape  3 bedrooms, 2 bathrooms, 2nd floor with elevator
# 1   2024-09-23  city scrape      Athens Quality Apartments - Deluxe Apartment
# 2   2024-09-23  city scrape                Athens Quality Apartments - Studio
# 3   2024-09-23  city scrape    AQA-No2 1-bedroom, smart tv, fiber connection,
# 4   2024-09-23  city scrape      AQA-No7, Great mattress, high speed internet
#
#                                          description  \
# 0  The apartment is 3-bedroom apartment with 2-ba...
# 1  Athens Quality Apartments - Deluxe apartment i...
# 2  The Studio is an <br />-excellent located <br ...
# 3  AQA No2 is 1-bedroom apartment (47m2), on the ...
# 4  THE MATTRESS - KING KOIL - Camden Luxury 160x2...
#
#                                neighborhood_overview  host_name  host_since  \
# ...

# %%
# Crear la carpeta del país si no existe
pais = 'Grecia'
carpeta_pais = f"room_type_{pais}"
os.makedirs(carpeta_pais, exist_ok=True)

for room_type, data in room_type_datasets.items():
    # Limpiar el nombre del archivo (eliminar caracteres problemáticos y reemplazar espacios)
    sanitized_name = re.sub(r'[^\w\s]', '', room_type).replace(' ', '_')
    
    # Construir la ruta del archivo dentro de la carpeta del país
    filename = os.path.join(carpeta_pais, f"{sanitized_name}_{pais}.csv")
    
    # Guardar el dataset en un archivo CSV
    data.to_csv(filename, index=False)

    print(f"Archivo guardado en: {filename}")
# Out:
# Archivo guardado en: room_type_Grecia\Entire_homeapt_Grecia.csv
# Archivo guardado en: room_type_Grecia\Hotel_room_Grecia.csv
# Archivo guardado en: room_type_Grecia\Private_room_Grecia.csv
# Archivo guardado en: room_type_Grecia\Shared_room_Grecia.csv

# %% [markdown]
# # **| Separación del Dataset México**

# %%
#Cargar desde un archivo .csv
df = pd.read_csv('México.csv')
Mexico = df.drop(['Unnamed: 0'], axis=1)

Mexico.head()
# Out:
#   last_scraped           source  \
# 0   2024-09-25      city scrape
# 1   2024-09-26  previous scrape
# 2   2024-09-26      city scrape
# 3   2024-09-25      city scrape
# 4   2024-09-25      city scrape
#
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# ...

# %%
# Separar los datos en diferentes datasets basados en el valor de "room_type"
room_type_groups = Mexico.groupby('room_type')

# Crear un diccionario para almacenar los datasets separados
room_type_datasets = {room_type: data for room_type, data in room_type_groups}

# Mostrar los nombres de los datasets creados
room_type_datasets.keys()
# Out:
# dict_keys(['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'])

# %%
for room_type, data in room_type_datasets.items():
    print(f"Dataset: {room_type}")
    display(data.head())
# Out:
# Dataset: Entire home/apt
#   last_scraped           source  \
# 0   2024-09-25      city scrape
# 1   2024-09-26  previous scrape
# 2   2024-09-26      city scrape
# 3   2024-09-25      city scrape
# 4   2024-09-25      city scrape
#
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# ...

# %%
# Crear la carpeta del país si no existe
pais = 'México'
carpeta_pais = f"room_type_{pais}"
os.makedirs(carpeta_pais, exist_ok=True)

for room_type, data in room_type_datasets.items():
    # Limpiar el nombre del archivo (eliminar caracteres problemáticos y reemplazar espacios)
    sanitized_name = re.sub(r'[^\w\s]', '', room_type).replace(' ', '_')
    
    # Construir la ruta del archivo dentro de la carpeta del país
    filename = os.path.join(carpeta_pais, f"{sanitized_name}_{pais}.csv")
    
    # Guardar el dataset en un archivo CSV
    data.to_csv(filename, index=False)

    print(f"Archivo guardado en: {filename}")
# Out:
# Archivo guardado en: room_type_México\Entire_homeapt_México.csv
# Archivo guardado en: room_type_México\Hotel_room_México.csv
# Archivo guardado en: room_type_México\Private_room_México.csv
# Archivo guardado en: room_type_México\Shared_room_México.csv
